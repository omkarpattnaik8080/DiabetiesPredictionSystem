# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/DiabetiesPredictionSystem/blob/main/DiabetiesPredictionSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler #used to standedise the data to a common range
from sklearn.model_selection import train_test_split #used to split the data into tarining set data
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection & Analysis

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#getting the statistical measures of the dataframe
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269      69.115735      20.509753   79.697009
# std       3.370237   31.951886      19.345296      15.959020  115.203999
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   29.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               769 non-null    int64
#  1   Glucose                   769 non-null    int64
#  2   BloodPressure             769 non-null    int64
#  3   SkinThickness             769 non-null    int64
#  4   Insulin                   769 non-null    int64
#  5   BMI                       769 non-null    float64
#  6   DiabetesPedigreeFunction  769 non-null    float64
#  7   Age                       769 non-null    int64
#  8   Outcome                   769 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.2 KB

# %%
df.shape
# Out:
# (769, 9)

# %%
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    269
# Name: Outcome, dtype: int64

# %%
df.groupby("Outcome").mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000  68.792000
# 1           4.847584  141.189591      70.847584      22.081784  99.966543
#
#               BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.30420                  0.429734  31.190000
# 1        35.14684                  0.549390  37.133829

# %% [markdown]
# **Separating the data and labels**

# %%
X=df.drop(columns="Outcome",axis=1)
Y=df["Outcome"]

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
# 768            0      123             77              0        1  36.3
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 764    0
# 765    0
# 766    1
# 767    0
# 768    1
# Name: Outcome, Length: 769, dtype: int64

# %% [markdown]
# **Data Standardization**

# %%
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standerdized_data=scaler.transform(X)
